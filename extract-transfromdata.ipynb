# %% [markdown]
# ## **Setup**

# %% [markdown]
# Buatlah file Google Spreadsheet di personal account Google Drive. Import data dari URL Google Spreadsheet Aruna.

# %% [markdown]
# > Menggunakan fungsi IMPORTRANGE

# %% [markdown]
# Link Google Spreadsheet :
#
# <b> https://docs.google.com/spreadsheets/d/1mYPXtMXQ8-wvwBq0WsDjDTUqIGElSVl1mdDuhSWGsdI/edit?usp=sharing

# %% [markdown]
# Extract and Transformation dari Google Sheet menjadi files dengan parquet extension sesuai dengan transaction type.

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# Sheet Name:
# - BKJ_Delivery
# - BKJ_Buying
# - BKJ_Processing
# - DOB_Delivery
# - DOB_Buying
# - DOB_Processing

# %% [markdown]
# Import Library

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install fastparquet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastparquet
#   Downloading fastparquet-2022.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 3.8 MB/s
# Collecting pandas>=1.5.0
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 28.5 MB/s
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.21.6)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 27.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastparquet) (21.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.5.0->fastparquet) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->fastparquet) (3.0.9)
# Installing collected packages: pandas, cramjam, fastparquet
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed cramjam-2.6.2 fastparquet-2022.12.0 pandas-1.5.2

# %%
import pandas as pd
import pyarrow
import fastparquet

# %%
 pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# ## **Data Extraction, Data Transformation and Data Cleaning**

# %% [markdown]
# Data Extraction from Google Spreadsheet

# %%
sheet_id = '1mYPXtMXQ8-wvwBq0WsDjDTUqIGElSVl1mdDuhSWGsdI'
sheet_name = ['BKJ_Delivery', 'BKJ_Buying', 'BKJ_Processing', 'DOB_Delivery', 'DOB_Buying', 'DOB_Processing']

BKJ_Delivery = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[0]}"
BKJ_Buying = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[1]}"
BKJ_Processing = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[2]}"
DOB_Delivery = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[3]}"
DOB_Buying = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[4]}"
DOB_Processing = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name[5]}"

# %% [markdown]
# ### **BKJ Delivery**

# %%
#Read data csv
df = pd.read_csv(BKJ_Delivery)

# %%
#Melihat nama kolom
df.columns
# Out:
# Index(['Norm Helper', 'Delivery Number', 'Tanggal Delivery dari MP',
#        'Buyer Name', 'Product Kirim', 'Tanggal Diterima Buyer', 'Unnamed: 6'],
#       dtype='object')

# %%
#Data cleaning : menghapus kolom 'Unnamed: 6'
df = df.drop('Unnamed: 6', axis=1)
df.columns
# Out:
# Index(['Norm Helper', 'Delivery Number', 'Tanggal Delivery dari MP',
#        'Buyer Name', 'Product Kirim', 'Tanggal Diterima Buyer'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df.to_parquet('BKJ_Delivery.parquet', index=False)
#Menyimpan file parquet di Google Drive
# !cp BKJ_Delivery.parquet "drive/My Drive/"

# %%
#Read data parquet
df_BKJ_Delivery = pd.read_parquet('BKJ_Delivery.parquet')

# %%
#Preview data
df_BKJ_Delivery.head()
# Out:
#              Norm Helper  Delivery Number Tanggal Delivery dari MP Buyer Name  \
# 0  DO/BKJ/20220305/001/1                1               05/03/2022   PT Prima
# 1  DO/BKJ/20220307/002/1                2               07/03/2022   PT Prima
# 2  DO/BKJ/20220309/003/1                3               09/03/2022   PT Prima
#
#   Product Kirim Tanggal Diterima Buyer
# 0  Tuna (Whole)             06/03/2022
# 1  Tuna (Whole)             08/03/2022
# 2  Tuna (Whole)             10/03/2022

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_BKJ_Delivery.shape
# Out:
# (3, 6)

# %%
#Summary data info
df_BKJ_Delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Norm Helper               3 non-null      object
#  1   Delivery Number           3 non-null      int64
#  2   Tanggal Delivery dari MP  3 non-null      object
#  3   Buyer Name                3 non-null      object
#  4   Product Kirim             3 non-null      object
#  5   Tanggal Diterima Buyer    3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 272.0+ bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Tidak ada missing value (data hilang/ data kosong)
# - Kolom `Tanggal Delivery dari MP` dan `Tanggal Diterima Buyer` memiliki tipe data yang salah yaitu object, seharusnya berformat datetime

# %%
#Data transformation : mengubah tipe data menjadi datetime
df_BKJ_Delivery['Tanggal Delivery dari MP'] = pd.to_datetime(df_BKJ_Delivery['Tanggal Delivery dari MP'], dayfirst=True)
df_BKJ_Delivery['Tanggal Diterima Buyer'] = pd.to_datetime(df_BKJ_Delivery['Tanggal Diterima Buyer'], dayfirst=True)

# %%
#Check tipe data
df_BKJ_Delivery.dtypes
# Out:
# Norm Helper                         object
# Delivery Number                      int64
# Tanggal Delivery dari MP    datetime64[ns]
# Buyer Name                          object
# Product Kirim                       object
# Tanggal Diterima Buyer      datetime64[ns]
# dtype: object

# %%
#Check duplicated data
df_BKJ_Delivery.duplicated(subset='Norm Helper', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### **BKJ Buying**

# %%
#Read data csv
df2 = pd.read_csv(BKJ_Buying)

# %%
#Melihat nama kolom
df2.columns
# Out:
# Index(['PO Number', 'Date Helper', 'Norm Helper', 'Date', 'Month', 'Year',
#        'Nama Nelayan/Supplier', 'Type', 'Source Place', 'Category', 'Items',
#        'Size', 'Code', 'Quantity', 'Kupon', 'Price', 'Amount', 'ID Nelayan',
#        'Sequence 1', 'Sequence 2'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df2.to_parquet('BKJ_Buying.parquet')
#Menyimpan file parquet di Google Drive
# !cp BKJ_Buying.parquet "drive/My Drive/"

# %%
#Read data parquet
df_BKJ_Buying = pd.read_parquet('BKJ_Buying.parquet')

# %%
#Preview data
df_BKJ_Buying.head()
# Out:
#              PO Number Date Helper            Norm Helper        Date Month  \
# 0  PO/BKJ/20220305/001  05/03/2022  DO/BKJ/20220305/001/1  05/03/2022   Mar
# 1  PO/BKJ/20220305/002  05/03/2022  DO/BKJ/20220305/001/1  05/03/2022   Mar
# 2  PO/BKJ/20220306/001  06/03/2022  DO/BKJ/20220307/002/1  06/03/2022   Mar
#
#    Year Nama Nelayan/Supplier        Type Source Place      Category Items  \
# 0  2022                 Nazar  Mini Plant  Bangka Jaya  Ikan Pelagis  Tuna
# 1  2022                  Moza    Supplier  Krueng Mane  Ikan Pelagis  Tuna
# 2  2022                   Gam    Supplier  Bangka Jaya  Ikan Pelagis  Tuna
#
#    Size     Code  Quantity  Kupon  Price      Amount  ID Nelayan  Sequence 1  \
# 0   NaN  TUNA 20       248    NaN   29.0  10.664.000         NaN           1
# 1   NaN  TUNA 20       252    NaN   29.0  10.836.000         NaN           2
# 2   NaN  TUNA 20        30    NaN   29.0   1.290.000         NaN           1
#
#    Sequence 2
# 0           1
# 1           2
# 2           1

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_BKJ_Buying.shape
# Out:
# (3, 20)

# %%
#Summary data info
df_BKJ_Buying.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PO Number              3 non-null      object
#  1   Date Helper            3 non-null      object
#  2   Norm Helper            3 non-null      object
#  3   Date                   3 non-null      object
#  4   Month                  3 non-null      object
#  5   Year                   3 non-null      int64
#  6   Nama Nelayan/Supplier  3 non-null      object
#  7   Type                   3 non-null      object
#  8   Source Place           3 non-null      object
#  9   Category               3 non-null      object
#  10  Items                  3 non-null      object
#  11  Size                   0 non-null      float64
#  12  Code                   3 non-null      object
#  13  Quantity               3 non-null      int64
#  14  Kupon                  0 non-null      float64
#  15  Price                  3 non-null      float64
#  16  Amount                 3 non-null      object
#  17  ID Nelayan             0 non-null      float64
#  18  Sequence 1             3 non-null      int64
#  19  Sequence 2             3 non-null      int64
# dtypes: float64(4), int64(4), object(12)
# memory usage: 608.0+ bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Terdapat missing value (data hilang/ data kosong) pada kolom `Size`, `Kupon`, dan `ID Nelayan`
# - Kolom `ID Nelayan` menunjukkan sebuah ID yang dalam database seharusnya memiliki tipe interger
# - Kolom `Date Helper` dan `Date` seharusnya berformat datetime
# - Kolom `Price` memiliki data yang seharusnya menunjukkan harga dalam ribuan (contoh: 29000)
# - Kolom `Amount` yang menunjukkan total harga (quantity*price) memiliki tipe data yang salah yaitu object, seharusnya berformat number (int)

# %%
#Data cleaning : mengisi missing value dengan nilai 0 (karena memang tidak diketahui)
df_BKJ_Buying = df_BKJ_Buying.fillna(0)

# %%
#Data transformation : mengubah tipe data dari float --> int
df_BKJ_Buying['ID Nelayan'] = df_BKJ_Buying['ID Nelayan'].astype('int64')
df_BKJ_Buying['Price'] = df_BKJ_Buying['Price'].astype('int64')

# %%
#Data transformation : mengubah tipe data menjadi datetime
df_BKJ_Buying['Date Helper'] = pd.to_datetime(df_BKJ_Buying['Date Helper'], dayfirst=True)
df_BKJ_Buying['Date'] = pd.to_datetime(df_BKJ_Buying['Date'], dayfirst=True)

# %%
#Data transformation : mengubah nilai price dalam bentuk ribuan
numbers = df_BKJ_Buying['Price'].tolist()
df_BKJ_Buying['Price'] = [int(str(num).ljust(5, '0')) for num in numbers]

# %%
#Data transformation : mengubah tipe data dari object --> int
df_BKJ_Buying['Amount'] = df_BKJ_Buying['Amount'].str.replace('.','')
df_BKJ_Buying['Amount'] = df_BKJ_Buying['Amount'].astype('int64')
# Out:
# <ipython-input-28-a4c6deace3e9>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_BKJ_Buying['Amount'] = df_BKJ_Buying['Amount'].str.replace('.','')

# %%
#Untuk menyamakan dengan tipe data pada DOB_Buying
df_BKJ_Buying['Quantity'] = df_BKJ_Buying['Quantity'].astype('float64')

# %%
#Preview Data After
df_BKJ_Buying.head()
# Out:
#              PO Number Date Helper            Norm Helper       Date Month  \
# 0  PO/BKJ/20220305/001  2022-03-05  DO/BKJ/20220305/001/1 2022-03-05   Mar
# 1  PO/BKJ/20220305/002  2022-03-05  DO/BKJ/20220305/001/1 2022-03-05   Mar
# 2  PO/BKJ/20220306/001  2022-03-06  DO/BKJ/20220307/002/1 2022-03-06   Mar
#
#    Year Nama Nelayan/Supplier        Type Source Place      Category Items  \
# 0  2022                 Nazar  Mini Plant  Bangka Jaya  Ikan Pelagis  Tuna
# 1  2022                  Moza    Supplier  Krueng Mane  Ikan Pelagis  Tuna
# 2  2022                   Gam    Supplier  Bangka Jaya  Ikan Pelagis  Tuna
#
#    Size     Code  Quantity  Kupon  Price    Amount  ID Nelayan  Sequence 1  \
# 0   0.0  TUNA 20     248.0    0.0  29000  10664000           0           1
# 1   0.0  TUNA 20     252.0    0.0  29000  10836000           0           2
# 2   0.0  TUNA 20      30.0    0.0  29000   1290000           0           1
#
#    Sequence 2
# 0           1
# 1           2
# 2           1

# %%
#Check tipe data
df_BKJ_Buying.dtypes
# Out:
# PO Number                        object
# Date Helper              datetime64[ns]
# Norm Helper                      object
# Date                     datetime64[ns]
# Month                            object
# Year                              int64
# Nama Nelayan/Supplier            object
# Type                             object
# Source Place                     object
# Category                         object
# Items                            object
# Size                            float64
# Code                             object
# Quantity                        float64
# Kupon                           float64
# Price                             int64
# Amount                            int64
# ID Nelayan                        int64
# Sequence 1                        int64
# Sequence 2                        int64
# dtype: object

# %%
#Check duplicated data
df_BKJ_Buying.duplicated(subset='PO Number', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### **BKJ Processing**

# %%
#Read data csv
df3 = pd.read_csv(BKJ_Processing)

# %%
#Melihat nama kolom
df3.columns
# Out:
# Index(['PR No', 'Date helper', 'Norm Helper', 'Date', 'RM', 'RC', '%',
#        'Total RC', 'RC Dback', '%.1', 'Total RC Dback', 'Meat', '%.2',
#        'Total Meat', 'Picker Price', 'Amount', 'Sequence 1', 'Sequence 2'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df3.to_parquet('BKJ_Processing.parquet')
#Menyimpan file parquet di Google Drive
# !cp BKJ_Processing.parquet "drive/My Drive/"

# %%
#Read data parquet
df_BKJ_Processing = pd.read_parquet('BKJ_Processing.parquet')

# %%
#Preview data
df_BKJ_Processing.head()
# Out:
#    PR No  Date helper  Norm Helper  Date  RM  RC   %  Total RC  RC Dback  %.1  \
# 0    NaN          NaN          NaN   NaN NaN NaN NaN       NaN       NaN  NaN
#
#    Total RC Dback  Meat  %.2  Total Meat  Picker Price  Amount  Sequence 1  \
# 0             NaN   NaN  NaN         NaN           NaN     NaN         NaN
#
#    Sequence 2
# 0         NaN

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_BKJ_Processing.shape
# Out:
# (1, 18)

# %%
#Summary data info
df_BKJ_Processing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PR No           0 non-null      float64
#  1   Date helper     0 non-null      float64
#  2   Norm Helper     0 non-null      float64
#  3   Date            0 non-null      float64
#  4   RM              0 non-null      float64
#  5   RC              0 non-null      float64
#  6   %               0 non-null      float64
#  7   Total RC        0 non-null      float64
#  8   RC Dback        0 non-null      float64
#  9   %.1             0 non-null      float64
#  10  Total RC Dback  0 non-null      float64
#  11  Meat            0 non-null      float64
#  12  %.2             0 non-null      float64
#  13  Total Meat      0 non-null      float64
#  14  Picker Price    0 non-null      float64
#  15  Amount          0 non-null      float64
#  16  Sequence 1      0 non-null      float64
#  17  Sequence 2      0 non-null      float64
# dtypes: float64(18)
# memory usage: 272.0 bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Terdapat missing value (data hilang/ data kosong) pada semua kolom
# - Akan mengubah tipe data yang masih salah

# %%
#Mengisi missing value dengan 0
df_BKJ_Processing = df_BKJ_Processing.fillna(0)

# %%
#Data transformation : mengubah tipe data float --> object
df_BKJ_Processing['PR No'] = df_BKJ_Processing['PR No'].astype(str)
df_BKJ_Processing['Norm Helper'] = df_BKJ_Processing['Norm Helper'].astype(str)

# %%
#Data transformation : mengubah tipe data float --> int
df_BKJ_Processing['Amount'] = df_BKJ_Processing['Amount'].astype('int64')
df_BKJ_Processing['Sequence 1'] = df_BKJ_Processing['Sequence 1'].astype('int64')
df_BKJ_Processing['Sequence 2'] = df_BKJ_Processing['Sequence 2'].astype('int64')

# %%
#Data transformation : mengubah tipe data float --> datetime
df_BKJ_Processing['Date helper'] = pd.to_datetime(df_BKJ_Processing['Date helper'])
df_BKJ_Processing['Date'] = pd.to_datetime(df_BKJ_Processing['Date'])

# %%
#Delete row
df_BKJ_Processing = df_BKJ_Processing.drop(index = [0])

# %%
#Preview Data After
df_BKJ_Processing.head()
# Out:
# Empty DataFrame
# Columns: [PR No, Date helper, Norm Helper, Date, RM, RC, %, Total RC, RC Dback, %.1, Total RC Dback, Meat, %.2, Total Meat, Picker Price, Amount, Sequence 1, Sequence 2]
# Index: []

# %%
#Check tipe data
df_BKJ_Processing.dtypes
# Out:
# PR No                     object
# Date helper       datetime64[ns]
# Norm Helper               object
# Date              datetime64[ns]
# RM                       float64
# RC                       float64
# %                        float64
# Total RC                 float64
# RC Dback                 float64
# %.1                      float64
# Total RC Dback           float64
# Meat                     float64
# %.2                      float64
# Total Meat               float64
# Picker Price             float64
# Amount                     int64
# Sequence 1                 int64
# Sequence 2                 int64
# dtype: object

# %%
#Check duplicated data
df_BKJ_Processing.duplicated(subset='PR No', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### **DOB Delivery**

# %%
#Read data csv
df4 = pd.read_csv(DOB_Delivery)

# %%
#Melihat nama kolom
df4.columns
# Out:
# Index(['Norm Helper', 'Delivery Number', 'Tanggal Delivery dari MP',
#        'Buyer Name', 'Product Kirim', 'Tanggal Diterima Buyer', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
cols_to_drop = [ 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25' ]

# %%
#Data cleaning : menghapus semua kolom Unnamed
df4 = df4.drop(cols_to_drop, axis=1)
df4.columns
# Out:
# Index(['Norm Helper', 'Delivery Number', 'Tanggal Delivery dari MP',
#        'Buyer Name', 'Product Kirim', 'Tanggal Diterima Buyer'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df4.to_parquet('DOB_Delivery.parquet')
#Menyimpan file parquet di Google Drive
# !cp DOB_Delivery.parquet "drive/My Drive/"

# %%
#Read data parquet
df_DOB_Delivery = pd.read_parquet('DOB_Delivery.parquet')

# %%
#Preview data
df_DOB_Delivery.head(10)
# Out:
#              Norm Helper  Delivery Number Tanggal Delivery dari MP  \
# 0  DO/DOB/20220104/090/1               90               04/01/2022
# 1  DO/DOB/20220105/091/1               91               05/01/2022
# 2  DO/DOB/20220106/092/1               92               06/01/2022
# 3  DO/DOB/20220107/093/1               93               07/01/2022
# 4  DO/DOB/20220108/094/1               94               08/01/2022
# 5  DO/DOB/20220109/095/1               95               09/01/2022
# 6  DO/DOB/20220110/096/1               96               10/01/2022
# 7  DO/DOB/20220111/097/1               97               11/01/2022
# 8  DO/DOB/20220113/098/1               98                     None
# 9  DO/DOB/20220114/099/1               99                     None
#
#        Buyer Name    Product Kirim Tanggal Diterima Buyer
# 0     SJA Lampung  Rajungan (Meat)             05/01/2022
# 1     SJA Lampung  Rajungan (Meat)             06/01/2022
# 2     SJA Lampung  Rajungan (Meat)             07/01/2022
# 3     SJA Lampung  Rajungan (Meat)             08/01/2022
# 4  Nirwana Segara  Rajungan (Meat)             09/01/2022
# 5  Nirwana Segara  Rajungan (Meat)             10/01/2022
# 6  Nirwana Segara  Rajungan (Meat)             11/01/2022
# 7  Nirwana Segara  Rajungan (Meat)             12/01/2022
# 8  Nirwana Segara  Rajungan (Meat)                   None
# 9  Nirwana Segara  Rajungan (Meat)                   None

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_DOB_Delivery.shape
# Out:
# (10, 6)

# %%
#Summary data info
df_DOB_Delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Norm Helper               10 non-null     object
#  1   Delivery Number           10 non-null     int64
#  2   Tanggal Delivery dari MP  8 non-null      object
#  3   Buyer Name                10 non-null     object
#  4   Product Kirim             10 non-null     object
#  5   Tanggal Diterima Buyer    8 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 608.0+ bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Terdapat missing value (data hilang/ data kosong) pada kolom `Tanggal Delivery dari MP` dan `Tanggal Diterima Buyer`
# - Kolom `Tanggal Delivery dari MP` dan `Tanggal Diterima Buyer` seharusnya berformat datetime

# %%
#Data cleaning : mengsisi missing value dengan nilai tanggal sebenarnya pada data di spreadsheet
df_DOB_Delivery.iloc[8, 2] = '13/01/2022'
df_DOB_Delivery.iloc[9, 2] = '14/01/2022'
df_DOB_Delivery.iloc[8, 5] = '14/01/2022'
df_DOB_Delivery.iloc[9, 5] = '15/01/2022'

# %%
#Data transformation : mengubah tipe data menjadi datetime
df_DOB_Delivery['Tanggal Delivery dari MP'] = pd.to_datetime(df_DOB_Delivery['Tanggal Delivery dari MP'], dayfirst=True)
df_DOB_Delivery['Tanggal Diterima Buyer'] = pd.to_datetime(df_DOB_Delivery['Tanggal Diterima Buyer'], dayfirst=True)

# %%
#Preview Data After
df_DOB_Delivery.head(10)
# Out:
#              Norm Helper  Delivery Number Tanggal Delivery dari MP  \
# 0  DO/DOB/20220104/090/1               90               2022-01-04
# 1  DO/DOB/20220105/091/1               91               2022-01-05
# 2  DO/DOB/20220106/092/1               92               2022-01-06
# 3  DO/DOB/20220107/093/1               93               2022-01-07
# 4  DO/DOB/20220108/094/1               94               2022-01-08
# 5  DO/DOB/20220109/095/1               95               2022-01-09
# 6  DO/DOB/20220110/096/1               96               2022-01-10
# 7  DO/DOB/20220111/097/1               97               2022-01-11
# 8  DO/DOB/20220113/098/1               98               2022-01-13
# 9  DO/DOB/20220114/099/1               99               2022-01-14
#
#        Buyer Name    Product Kirim Tanggal Diterima Buyer
# 0     SJA Lampung  Rajungan (Meat)             2022-01-05
# 1     SJA Lampung  Rajungan (Meat)             2022-01-06
# 2     SJA Lampung  Rajungan (Meat)             2022-01-07
# 3     SJA Lampung  Rajungan (Meat)             2022-01-08
# 4  Nirwana Segara  Rajungan (Meat)             2022-01-09
# 5  Nirwana Segara  Rajungan (Meat)             2022-01-10
# 6  Nirwana Segara  Rajungan (Meat)             2022-01-11
# 7  Nirwana Segara  Rajungan (Meat)             2022-01-12
# 8  Nirwana Segara  Rajungan (Meat)             2022-01-14
# 9  Nirwana Segara  Rajungan (Meat)             2022-01-15

# %%
#Check tipe data
df_DOB_Delivery.dtypes
# Out:
# Norm Helper                         object
# Delivery Number                      int64
# Tanggal Delivery dari MP    datetime64[ns]
# Buyer Name                          object
# Product Kirim                       object
# Tanggal Diterima Buyer      datetime64[ns]
# dtype: object

# %%
#Check duplicated data
df_DOB_Delivery.duplicated(subset='Norm Helper', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### **DOB Buying**

# %%
#Read data csv
df5 = pd.read_csv(DOB_Buying)

# %%
#Melihat nama kolom
df5.columns
# Out:
# Index(['PO Number', 'Date Helper', 'Norm Helper', 'Date', 'Month', 'Year',
#        'Nama Nelayan/Supplier', 'Type', 'Source Place', 'Category', 'Items',
#        'Size', 'Code', 'Quantity', 'Kupon', 'Price', 'Amount', 'ID Nelayan',
#        'Sequence 1', 'Sequence 2'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df5.to_parquet('DOB_Buying.parquet')
#Menyimpan file parquet di Google Drive
# !cp DOB_Buying.parquet "drive/My Drive/"

# %%
#Read data parquet
df_DOB_Buying = pd.read_parquet('DOB_Buying.parquet')

# %%
#Preview data
df_DOB_Buying.head()
# Out:
#              PO Number Date Helper            Norm Helper        Date Month  \
# 0  PO/DOB/20220103/001  03/01/2022  DO/DOB/20220104/090/1  03/01/2022   Jan
# 1  PO/DOB/20220103/002  03/01/2022  DO/DOB/20220104/090/1  03/01/2022   Jan
# 2  PO/DOB/20220104/001  04/01/2022  DO/DOB/20220105/091/1  04/01/2022   Jan
# 3  PO/DOB/20220104/002  04/01/2022  DO/DOB/20220105/091/1  04/01/2022   Jan
# 4  PO/DOB/20220105/001  05/01/2022  DO/DOB/20220106/092/1  05/01/2022   Jan
#
#    Year Nama Nelayan/Supplier      Type   Source Place  Category     Items  \
# 0  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
# 1  2022                  Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan
# 2  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
# 3  2022                  Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan
# 4  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
#
#    Size  Code Quantity  Kupon  Price     Amount  ID Nelayan  Sequence 1  \
# 0   NaN    RC       70    NaN   35.0  2.450.000         NaN           1
# 1   NaN  MEAT     14,4    NaN  355.0  5.112.000         NaN           2
# 2   NaN    RC      100    NaN   35.0  3.500.000         NaN           1
# 3   NaN  MEAT     9,86    NaN  355.0  3.500.300         NaN           2
# 4   NaN    RC       20    NaN   35.0    700.000         NaN           1
#
#    Sequence 2
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_DOB_Buying.shape
# Out:
# (5, 20)

# %%
#Summary data info
df_DOB_Buying.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PO Number              5 non-null      object
#  1   Date Helper            5 non-null      object
#  2   Norm Helper            5 non-null      object
#  3   Date                   5 non-null      object
#  4   Month                  5 non-null      object
#  5   Year                   5 non-null      int64
#  6   Nama Nelayan/Supplier  5 non-null      object
#  7   Type                   5 non-null      object
#  8   Source Place           5 non-null      object
#  9   Category               5 non-null      object
#  10  Items                  5 non-null      object
#  11  Size                   0 non-null      float64
#  12  Code                   5 non-null      object
#  13  Quantity               5 non-null      object
#  14  Kupon                  0 non-null      float64
#  15  Price                  5 non-null      float64
#  16  Amount                 5 non-null      object
#  17  ID Nelayan             0 non-null      float64
#  18  Sequence 1             5 non-null      int64
#  19  Sequence 2             5 non-null      int64
# dtypes: float64(4), int64(3), object(13)
# memory usage: 928.0+ bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Terdapat missing value (data hilang/ data kosong) pada kolom `Size`, `Kupon`, dan `ID Nelayan`
# - Kolom `ID Nelayan` menunjukkan sebuah ID yang dalam database seharusnya memiliki tipe interger
# - Kolom `Date Helper` dan `Date` seharusnya berformat datetime
# - Kolom `Price` memiliki data yang seharusnya menunjukkan harga dalam ribuan (contoh: 35000)
# - Kolom `Amount` yang menunjukkan total harga (quantity*price) memiliki tipe data yang salah yaitu object, seharusnya berformat number (int)
# - Kolom `Quantity` seharusnya memiliki tipe number (float/int)

# %%
#Data cleaning : mengisi missing value dengan nilai 0 (karena memang tidak diketahui)
df_DOB_Buying = df_DOB_Buying.fillna(0)

# %%
#Data transformation : mengubah tipe data dari float --> int
df_DOB_Buying['ID Nelayan'] = df_DOB_Buying['ID Nelayan'].astype('int64')

# %%
#Data transformation : mengubah tipe data menjadi datetime
df_DOB_Buying['Date Helper'] = pd.to_datetime(df_DOB_Buying['Date Helper'], dayfirst=True)
df_DOB_Buying['Date'] = pd.to_datetime(df_DOB_Buying['Date'], dayfirst=True)

# %%
#Data transformation : mengubah tipe data dari float --> string
df_DOB_Buying['Price'] = df_DOB_Buying['Price'].astype('string')

# %%
#Data transformation : mengubah nilai price dalam bentuk ribuan
N = 2
numbers = df_DOB_Buying['Price'].tolist()
df_DOB_Buying['Price'] = [str(num).ljust(N + len(num), '0') for num in numbers]

# %%
#Data transformation : mengubah tipe data dari string --> int
df_DOB_Buying['Price'] = df_DOB_Buying['Price'].str.replace('.','')
df_DOB_Buying['Price'] = df_DOB_Buying['Price'].astype('int64')
# Out:
# <ipython-input-74-46eb7856ec79>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_DOB_Buying['Price'] = df_DOB_Buying['Price'].str.replace('.','')

# %%
#Data transformation : mengubah tipe data dari object --> int
df_DOB_Buying['Amount'] = df_DOB_Buying['Amount'].str.replace('.','')
df_DOB_Buying['Amount'] = df_DOB_Buying['Amount'].astype('int64')
# Out:
# <ipython-input-75-6d307b2f619c>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_DOB_Buying['Amount'] = df_DOB_Buying['Amount'].str.replace('.','')

# %%
#Data transformation : mengubah tipe data dari object --> float
df_DOB_Buying['Quantity'] = df_DOB_Buying['Quantity'].str.replace(',','.')
df_DOB_Buying['Quantity'] = df_DOB_Buying['Quantity'].astype('float64')

# %%
#Preview Data After
df_DOB_Buying.head()
# Out:
#              PO Number Date Helper            Norm Helper       Date Month  \
# 0  PO/DOB/20220103/001  2022-01-03  DO/DOB/20220104/090/1 2022-01-03   Jan
# 1  PO/DOB/20220103/002  2022-01-03  DO/DOB/20220104/090/1 2022-01-03   Jan
# 2  PO/DOB/20220104/001  2022-01-04  DO/DOB/20220105/091/1 2022-01-04   Jan
# 3  PO/DOB/20220104/002  2022-01-04  DO/DOB/20220105/091/1 2022-01-04   Jan
# 4  PO/DOB/20220105/001  2022-01-05  DO/DOB/20220106/092/1 2022-01-05   Jan
#
#    Year Nama Nelayan/Supplier      Type   Source Place  Category     Items  \
# 0  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
# 1  2022                  Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan
# 2  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
# 3  2022                  Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan
# 4  2022           MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan
#
#    Size  Code  Quantity  Kupon   Price   Amount  ID Nelayan  Sequence 1  \
# 0   0.0    RC     70.00    0.0   35000  2450000           0           1
# 1   0.0  MEAT     14.40    0.0  355000  5112000           0           2
# 2   0.0    RC    100.00    0.0   35000  3500000           0           1
# 3   0.0  MEAT      9.86    0.0  355000  3500300           0           2
# 4   0.0    RC     20.00    0.0   35000   700000           0           1
#
#    Sequence 2
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1

# %%
#Check tipe data
df_DOB_Buying.dtypes
# Out:
# PO Number                        object
# Date Helper              datetime64[ns]
# Norm Helper                      object
# Date                     datetime64[ns]
# Month                            object
# Year                              int64
# Nama Nelayan/Supplier            object
# Type                             object
# Source Place                     object
# Category                         object
# Items                            object
# Size                            float64
# Code                             object
# Quantity                        float64
# Kupon                           float64
# Price                             int64
# Amount                            int64
# ID Nelayan                        int64
# Sequence 1                        int64
# Sequence 2                        int64
# dtype: object

# %%
#Check duplicated data
df_DOB_Buying.duplicated(subset='PO Number', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### **DOB Processing**

# %%
#Read data csv
df6 = pd.read_csv(DOB_Processing)

# %%
#Melihat nama kolom
df6.columns
# Out:
# Index(['PR No', 'Date helper', 'Norm Helper', 'Date', 'RM', 'RC', '%',
#        'Total RC', 'RC Dback', '%.1', 'Total RC Dback', 'Meat', '%.2',
#        'Total Meat', 'Picker Price', 'Amount', 'Sequence 1', 'Sequence 2',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
cols_to_drop = [ 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25' ]

# %%
#Data cleaning : menghapus semua kolom Unnamed
df6 = df6.drop(cols_to_drop, axis=1)
df6.columns
# Out:
# Index(['PR No', 'Date helper', 'Norm Helper', 'Date', 'RM', 'RC', '%',
#        'Total RC', 'RC Dback', '%.1', 'Total RC Dback', 'Meat', '%.2',
#        'Total Meat', 'Picker Price', 'Amount', 'Sequence 1', 'Sequence 2'],
#       dtype='object')

# %%
#Data transformation : mengubah extention file yang semula CSV menjadi Parquet
df6.to_parquet('DOB_Processing.parquet')
#Menyimpan file parquet di Google Drive
# !cp DOB_Processing.parquet "drive/My Drive/"

# %%
#Read data parquet
df_DOB_Processing = pd.read_parquet('DOB_Processing.parquet')

# %%
#Preview data
df_DOB_Processing.head()
# Out:
#                  PR No Date helper            Norm Helper        Date  RM  \
# 0  PR/DOB/20220103/001  03/01/2022  DO/DOB/20220104/090/1  03/01/2022 NaN
# 1  PR/DOB/20220104/001  04/01/2022  DO/DOB/20220105/091/1  04/01/2022 NaN
# 2  PR/DOB/20220105/001  05/01/2022  DO/DOB/20220106/092/1  05/01/2022 NaN
# 3  PR/DOB/20220107/001  07/01/2022  DO/DOB/20220108/094/1  07/01/2022 NaN
# 4  PR/DOB/20220108/001  08/01/2022  DO/DOB/20220109/095/1  08/01/2022 NaN
#
#        RC     % Total RC  RC Dback  %.1  Total RC Dback   Meat  %.2  \
# 0      70  100%       70       NaN  NaN             NaN  19,35  28%
# 1     100  100%      100       NaN  NaN             NaN  26,21  26%
# 2      25  100%       25       NaN  NaN             NaN   7,40  30%
# 3   142,6  100%    142,6       NaN  NaN             NaN  35,65  25%
# 4  158,21  100%   158,21       NaN  NaN             NaN  38,05  24%
#
#   Total Meat  Picker Price     Amount  Sequence 1  Sequence 2
# 0      19,35          25.0    870.750           1           1
# 1      26,21          25.0  1.179.450           1           1
# 2       7,40          25.0    333.000           1           1
# 3      35,65          25.0  1.604.250           1           1
# 4      38,05          25.0  1.712.250           1           1

# %%
#Ukuran data (jumlah baris, jumlah kolom)
df_DOB_Processing.shape
# Out:
# (5, 18)

# %%
#Summary data info
df_DOB_Processing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PR No           5 non-null      object
#  1   Date helper     5 non-null      object
#  2   Norm Helper     5 non-null      object
#  3   Date            5 non-null      object
#  4   RM              0 non-null      float64
#  5   RC              5 non-null      object
#  6   %               5 non-null      object
#  7   Total RC        5 non-null      object
#  8   RC Dback        0 non-null      float64
#  9   %.1             0 non-null      float64
#  10  Total RC Dback  0 non-null      float64
#  11  Meat            5 non-null      object
#  12  %.2             5 non-null      object
#  13  Total Meat      5 non-null      object
#  14  Picker Price    5 non-null      float64
#  15  Amount          5 non-null      object
#  16  Sequence 1      5 non-null      int64
#  17  Sequence 2      5 non-null      int64
# dtypes: float64(5), int64(2), object(11)
# memory usage: 848.0+ bytes

# %% [markdown]
# Kesimpulan :
#
# ---
# - Terdapat missing value (data hilang/ data kosong) pada kolom `RM`, `RC Dback`, `%.1`, dan `Total RC Dback`
# - Kolom `Date Helper` dan `Date` seharusnya berformat datetime
# - Kolom `RC`, `%`, `Total RC`, `Meat`, `%.2`, dan `Total Meat` seharusnya bertipe number (float)
# - Kolom `Amount` yang menunjukkan total harga  memiliki tipe data yang salah yaitu object, seharusnya berformat number (int)

# %%
#Data cleaning : mengisi missing value dengan nilai 0 (karena memang tidak diketahui)
df_DOB_Processing = df_DOB_Processing.fillna(0)

# %%
#Data transformation : mengubah tipe data menjadi datetime
df_DOB_Processing['Date helper'] = pd.to_datetime(df_DOB_Processing['Date helper'], dayfirst=True)
df_DOB_Processing['Date'] = pd.to_datetime(df_DOB_Processing['Date'], dayfirst=True)

# %%
#Data transformation : mengubah tipe data dari object --> float
df_DOB_Processing['RC'] = df_DOB_Processing['RC'].str.replace(',','.')
df_DOB_Processing['RC'] = df_DOB_Processing['RC'].astype('float64')
df_DOB_Processing['Total RC'] = df_DOB_Processing['Total RC'].str.replace(',','.')
df_DOB_Processing['Total RC'] = df_DOB_Processing['Total RC'].astype('float64')
df_DOB_Processing['Total Meat'] = df_DOB_Processing['Total Meat'].str.replace(',','.')
df_DOB_Processing['Total Meat'] = df_DOB_Processing['Total Meat'].astype('float64')
df_DOB_Processing['Meat'] = df_DOB_Processing['Meat'].str.replace(',','.')
df_DOB_Processing['Meat'] = df_DOB_Processing['Meat'].astype('float64')

# %%
#Data transformation : mengubah tipe data dari object --> int
df_DOB_Processing['Amount'] = df_DOB_Processing['Amount'].str.replace('.','')
df_DOB_Processing['Amount'] = df_DOB_Processing['Amount'].astype('int64')
# Out:
# <ipython-input-92-717b22232ec1>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_DOB_Processing['Amount'] = df_DOB_Processing['Amount'].str.replace('.','')

# %%
#Data transformation : mengubah percentage menjadi float
df_DOB_Processing['%'] = (df_DOB_Processing['%'].str.replace('%',''))
df_DOB_Processing['%'] = df_DOB_Processing['%'].astype('float64')
df_DOB_Processing['%'] = df_DOB_Processing['%']/100
df_DOB_Processing['%.2'] = df_DOB_Processing['%.2'].str.replace('%','')
df_DOB_Processing['%.2'] = df_DOB_Processing['%.2'].astype('float64')
df_DOB_Processing['%.2'] = df_DOB_Processing['%.2']/100

# %%
#Preview Data After
df_DOB_Processing.head()
# Out:
#                  PR No Date helper            Norm Helper       Date   RM  \
# 0  PR/DOB/20220103/001  2022-01-03  DO/DOB/20220104/090/1 2022-01-03  0.0
# 1  PR/DOB/20220104/001  2022-01-04  DO/DOB/20220105/091/1 2022-01-04  0.0
# 2  PR/DOB/20220105/001  2022-01-05  DO/DOB/20220106/092/1 2022-01-05  0.0
# 3  PR/DOB/20220107/001  2022-01-07  DO/DOB/20220108/094/1 2022-01-07  0.0
# 4  PR/DOB/20220108/001  2022-01-08  DO/DOB/20220109/095/1 2022-01-08  0.0
#
#        RC    %  Total RC  RC Dback  %.1  Total RC Dback   Meat   %.2  \
# 0   70.00  1.0     70.00       0.0  0.0             0.0  19.35  0.28
# 1  100.00  1.0    100.00       0.0  0.0             0.0  26.21  0.26
# 2   25.00  1.0     25.00       0.0  0.0             0.0   7.40  0.30
# 3  142.60  1.0    142.60       0.0  0.0             0.0  35.65  0.25
# 4  158.21  1.0    158.21       0.0  0.0             0.0  38.05  0.24
#
#    Total Meat  Picker Price   Amount  Sequence 1  Sequence 2
# 0       19.35          25.0   870750           1           1
# 1       26.21          25.0  1179450           1           1
# 2        7.40          25.0   333000           1           1
# 3       35.65          25.0  1604250           1           1
# 4       38.05          25.0  1712250           1           1

# %%
#Check tipe data
df_DOB_Processing.dtypes
# Out:
# PR No                     object
# Date helper       datetime64[ns]
# Norm Helper               object
# Date              datetime64[ns]
# RM                       float64
# RC                       float64
# %                        float64
# Total RC                 float64
# RC Dback                 float64
# %.1                      float64
# Total RC Dback           float64
# Meat                     float64
# %.2                      float64
# Total Meat               float64
# Picker Price             float64
# Amount                     int64
# Sequence 1                 int64
# Sequence 2                 int64
# dtype: object

# %%
#Check duplicated data
df_DOB_Processing.duplicated(subset='PR No', keep='first').sum()
# Out:
# 0

# %% [markdown]
# ## **Join/ Concat Dataframe**

# %% [markdown]
# The concat() function can be used to concatenate two Dataframes by adding the rows of one to the other.

# %%
#Menggabungkan dataframe dengan transaksi delivery
df_all_delivery = pd.concat([df_BKJ_Delivery, df_DOB_Delivery])
df_all_delivery
# Out:
#              Norm Helper  Delivery Number Tanggal Delivery dari MP  \
# 0  DO/BKJ/20220305/001/1                1               2022-03-05
# 1  DO/BKJ/20220307/002/1                2               2022-03-07
# 2  DO/BKJ/20220309/003/1                3               2022-03-09
# 0  DO/DOB/20220104/090/1               90               2022-01-04
# 1  DO/DOB/20220105/091/1               91               2022-01-05
# 2  DO/DOB/20220106/092/1               92               2022-01-06
# 3  DO/DOB/20220107/093/1               93               2022-01-07
# 4  DO/DOB/20220108/094/1               94               2022-01-08
# 5  DO/DOB/20220109/095/1               95               2022-01-09
# 6  DO/DOB/20220110/096/1               96               2022-01-10
# 7  DO/DOB/20220111/097/1               97               2022-01-11
# 8  DO/DOB/20220113/098/1               98               2022-01-13
# 9  DO/DOB/20220114/099/1               99               2022-01-14
#
#        Buyer Name    Product Kirim Tanggal Diterima Buyer
# 0        PT Prima     Tuna (Whole)             2022-03-06
# 1        PT Prima     Tuna (Whole)             2022-03-08
# 2        PT Prima     Tuna (Whole)             2022-03-10
# 0     SJA Lampung  Rajungan (Meat)             2022-01-05
# 1     SJA Lampung  Rajungan (Meat)             2022-01-06
# 2     SJA Lampung  Rajungan (Meat)             2022-01-07
# 3     SJA Lampung  Rajungan (Meat)             2022-01-08
# 4  Nirwana Segara  Rajungan (Meat)             2022-01-09
# 5  Nirwana Segara  Rajungan (Meat)             2022-01-10
# 6  Nirwana Segara  Rajungan (Meat)             2022-01-11
# 7  Nirwana Segara  Rajungan (Meat)             2022-01-12
# 8  Nirwana Segara  Rajungan (Meat)             2022-01-14
# 9  Nirwana Segara  Rajungan (Meat)             2022-01-15

# %%
#Menggabungkan dataframe dengan transaksi buying
df_all_buying = pd.concat([df_BKJ_Buying, df_DOB_Buying])
df_all_buying
# Out:
#              PO Number Date Helper            Norm Helper       Date Month  \
# 0  PO/BKJ/20220305/001  2022-03-05  DO/BKJ/20220305/001/1 2022-03-05   Mar
# 1  PO/BKJ/20220305/002  2022-03-05  DO/BKJ/20220305/001/1 2022-03-05   Mar
# 2  PO/BKJ/20220306/001  2022-03-06  DO/BKJ/20220307/002/1 2022-03-06   Mar
# 0  PO/DOB/20220103/001  2022-01-03  DO/DOB/20220104/090/1 2022-01-03   Jan
# 1  PO/DOB/20220103/002  2022-01-03  DO/DOB/20220104/090/1 2022-01-03   Jan
# 2  PO/DOB/20220104/001  2022-01-04  DO/DOB/20220105/091/1 2022-01-04   Jan
# 3  PO/DOB/20220104/002  2022-01-04  DO/DOB/20220105/091/1 2022-01-04   Jan
# 4  PO/DOB/20220105/001  2022-01-05  DO/DOB/20220106/092/1 2022-01-05   Jan
#
#    Year Nama Nelayan/Supplier        Type   Source Place      Category  \
# 0  2022                 Nazar  Mini Plant    Bangka Jaya  Ikan Pelagis
# 1  2022                  Moza    Supplier    Krueng Mane  Ikan Pelagis
# 2  2022                   Gam    Supplier    Bangka Jaya  Ikan Pelagis
# 0  2022           MP Kaiwabar    Satelite       Kaiwabar      Rajungan
# 1  2022                  Inco    Supplier  Kepulauan Aru      Rajungan
# 2  2022           MP Kaiwabar    Satelite       Kaiwabar      Rajungan
# 3  2022                  Inco    Supplier  Kepulauan Aru      Rajungan
# 4  2022           MP Kaiwabar    Satelite       Kaiwabar      Rajungan
#
#       Items  Size     Code  Quantity  Kupon   Price    Amount  ID Nelayan  \
# 0      Tuna   0.0  TUNA 20    248.00    0.0   29000  10664000           0
# 1      Tuna   0.0  TUNA 20    252.00    0.0   29000  10836000           0
# 2      Tuna   0.0  TUNA 20     30.00    0.0   29000   1290000           0
# 0  Rajungan   0.0       RC     70.00    0.0   35000   2450000           0
# 1  Rajungan   0.0     MEAT     14.40    0.0  355000   5112000           0
# 2  Rajungan   0.0       RC    100.00    0.0   35000   3500000           0
# 3  Rajungan   0.0     MEAT      9.86    0.0  355000   3500300           0
# 4  Rajungan   0.0       RC     20.00    0.0   35000    700000           0
#
#    Sequence 1  Sequence 2
# 0           1           1
# 1           2           2
# 2           1           1
# 0           1           1
# 1           2           2
# 2           1           1
# 3           2           2
# 4           1           1

# %%
#Menggabungkan dataframe dengan transaksi processing
df_all_processing = pd.concat([df_BKJ_Processing, df_DOB_Processing])
df_all_processing
# Out:
#                  PR No Date helper            Norm Helper       Date   RM  \
# 0  PR/DOB/20220103/001  2022-01-03  DO/DOB/20220104/090/1 2022-01-03  0.0
# 1  PR/DOB/20220104/001  2022-01-04  DO/DOB/20220105/091/1 2022-01-04  0.0
# 2  PR/DOB/20220105/001  2022-01-05  DO/DOB/20220106/092/1 2022-01-05  0.0
# 3  PR/DOB/20220107/001  2022-01-07  DO/DOB/20220108/094/1 2022-01-07  0.0
# 4  PR/DOB/20220108/001  2022-01-08  DO/DOB/20220109/095/1 2022-01-08  0.0
#
#        RC    %  Total RC  RC Dback  %.1  Total RC Dback   Meat   %.2  \
# 0   70.00  1.0     70.00       0.0  0.0             0.0  19.35  0.28
# 1  100.00  1.0    100.00       0.0  0.0             0.0  26.21  0.26
# 2   25.00  1.0     25.00       0.0  0.0             0.0   7.40  0.30
# 3  142.60  1.0    142.60       0.0  0.0             0.0  35.65  0.25
# 4  158.21  1.0    158.21       0.0  0.0             0.0  38.05  0.24
#
#    Total Meat  Picker Price   Amount  Sequence 1  Sequence 2
# 0       19.35          25.0   870750           1           1
# 1       26.21          25.0  1179450           1           1
# 2        7.40          25.0   333000           1           1
# 3       35.65          25.0  1604250           1           1
# 4       38.05          25.0  1712250           1           1

# %% [markdown]
# The merge() function is equivalent to the SQL JOIN clause. ‘left’, ‘right’ and ‘inner’ joins are all possible.

# %%
#Menggabungkan dataframe dengan transaksi BKJ
df_all_BKJ = pd.merge(pd.merge(df_BKJ_Delivery, df_BKJ_Buying, on='Norm Helper', how='left'), df_BKJ_Processing, on='Norm Helper', how='left')
df_all_BKJ
# Out:
#              Norm Helper  Delivery Number Tanggal Delivery dari MP Buyer Name  \
# 0  DO/BKJ/20220305/001/1                1               2022-03-05   PT Prima
# 1  DO/BKJ/20220305/001/1                1               2022-03-05   PT Prima
# 2  DO/BKJ/20220307/002/1                2               2022-03-07   PT Prima
# 3  DO/BKJ/20220309/003/1                3               2022-03-09   PT Prima
#
#   Product Kirim Tanggal Diterima Buyer            PO Number Date Helper  \
# 0  Tuna (Whole)             2022-03-06  PO/BKJ/20220305/001  2022-03-05
# 1  Tuna (Whole)             2022-03-06  PO/BKJ/20220305/002  2022-03-05
# 2  Tuna (Whole)             2022-03-08  PO/BKJ/20220306/001  2022-03-06
# 3  Tuna (Whole)             2022-03-10                  NaN         NaT
#
#       Date_x Month    Year Nama Nelayan/Supplier        Type Source Place  \
# 0 2022-03-05   Mar  2022.0                 Nazar  Mini Plant  Bangka Jaya
# 1 2022-03-05   Mar  2022.0                  Moza    Supplier  Krueng Mane
# 2 2022-03-06   Mar  2022.0                   Gam    Supplier  Bangka Jaya
# 3        NaT   NaN     NaN                   NaN         NaN          NaN
#
#        Category Items  Size     Code  Quantity  Kupon    Price    Amount_x  \
# 0  Ikan Pelagis  Tuna   0.0  TUNA 20     248.0    0.0  29000.0  10664000.0
# 1  Ikan Pelagis  Tuna   0.0  TUNA 20     252.0    0.0  29000.0  10836000.0
# 2  Ikan Pelagis  Tuna   0.0  TUNA 20      30.0    0.0  29000.0   1290000.0
# 3           NaN   NaN   NaN      NaN       NaN    NaN      NaN         NaN
#
#    ID Nelayan  Sequence 1_x  Sequence 2_x PR No Date helper Date_y  RM  RC  \
# 0         0.0           1.0           1.0   NaN         NaT    NaT NaN NaN
# 1         0.0           2.0           2.0   NaN         NaT    NaT NaN NaN
# 2         0.0           1.0           1.0   NaN         NaT    NaT NaN NaN
# 3         NaN           NaN           NaN   NaN         NaT    NaT NaN NaN
#
#     %  Total RC  RC Dback  %.1  Total RC Dback  Meat  %.2  Total Meat  \
# 0 NaN       NaN       NaN  NaN             NaN   NaN  NaN         NaN
# 1 NaN       NaN       NaN  NaN             NaN   NaN  NaN         NaN
# 2 NaN       NaN       NaN  NaN             NaN   NaN  NaN         NaN
# 3 NaN       NaN       NaN  NaN             NaN   NaN  NaN         NaN
#
#    Picker Price  Amount_y  Sequence 1_y  Sequence 2_y
# 0           NaN       NaN           NaN           NaN
# 1           NaN       NaN           NaN           NaN
# 2           NaN       NaN           NaN           NaN
# 3           NaN       NaN           NaN           NaN

# %%
df_all_BKJ.shape
# Out:
# (4, 42)

# %%
#Menggabungkan dataframe dengan transaksi DOB
df_all_DOB = pd.merge(pd.merge(df_DOB_Delivery, df_DOB_Buying, on='Norm Helper', how='left'), df_DOB_Processing, on='Norm Helper', how='left')
df_all_DOB
# Out:
#               Norm Helper  Delivery Number Tanggal Delivery dari MP  \
# 0   DO/DOB/20220104/090/1               90               2022-01-04
# 1   DO/DOB/20220104/090/1               90               2022-01-04
# 2   DO/DOB/20220105/091/1               91               2022-01-05
# 3   DO/DOB/20220105/091/1               91               2022-01-05
# 4   DO/DOB/20220106/092/1               92               2022-01-06
# 5   DO/DOB/20220107/093/1               93               2022-01-07
# 6   DO/DOB/20220108/094/1               94               2022-01-08
# 7   DO/DOB/20220109/095/1               95               2022-01-09
# 8   DO/DOB/20220110/096/1               96               2022-01-10
# 9   DO/DOB/20220111/097/1               97               2022-01-11
# 10  DO/DOB/20220113/098/1               98               2022-01-13
# 11  DO/DOB/20220114/099/1               99               2022-01-14
#
#         Buyer Name    Product Kirim Tanggal Diterima Buyer  \
# 0      SJA Lampung  Rajungan (Meat)             2022-01-05
# 1      SJA Lampung  Rajungan (Meat)             2022-01-05
# 2      SJA Lampung  Rajungan (Meat)             2022-01-06
# 3      SJA Lampung  Rajungan (Meat)             2022-01-06
# 4      SJA Lampung  Rajungan (Meat)             2022-01-07
# 5      SJA Lampung  Rajungan (Meat)             2022-01-08
# 6   Nirwana Segara  Rajungan (Meat)             2022-01-09
# 7   Nirwana Segara  Rajungan (Meat)             2022-01-10
# 8   Nirwana Segara  Rajungan (Meat)             2022-01-11
# 9   Nirwana Segara  Rajungan (Meat)             2022-01-12
# 10  Nirwana Segara  Rajungan (Meat)             2022-01-14
# 11  Nirwana Segara  Rajungan (Meat)             2022-01-15
#
#               PO Number Date Helper     Date_x Month    Year  \
# 0   PO/DOB/20220103/001  2022-01-03 2022-01-03   Jan  2022.0
# 1   PO/DOB/20220103/002  2022-01-03 2022-01-03   Jan  2022.0
# 2   PO/DOB/20220104/001  2022-01-04 2022-01-04   Jan  2022.0
# 3   PO/DOB/20220104/002  2022-01-04 2022-01-04   Jan  2022.0
# 4   PO/DOB/20220105/001  2022-01-05 2022-01-05   Jan  2022.0
# 5                   NaN         NaT        NaT   NaN     NaN
# 6                   NaN         NaT        NaT   NaN     NaN
# 7                   NaN         NaT        NaT   NaN     NaN
# 8                   NaN         NaT        NaT   NaN     NaN
# 9                   NaN         NaT        NaT   NaN     NaN
# 10                  NaN         NaT        NaT   NaN     NaN
# 11                  NaN         NaT        NaT   NaN     NaN
#
#    Nama Nelayan/Supplier      Type   Source Place  Category     Items  Size  \
# 0            MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan   0.0
# 1                   Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan   0.0
# 2            MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan   0.0
# 3                   Inco  Supplier  Kepulauan Aru  Rajungan  Rajungan   0.0
# 4            MP Kaiwabar  Satelite       Kaiwabar  Rajungan  Rajungan   0.0
# 5                    NaN       NaN            NaN       NaN       NaN   NaN
# 6                    NaN       NaN            NaN       NaN       NaN   NaN
# 7                    NaN       NaN            NaN       NaN       NaN   NaN
# 8                    NaN       NaN            NaN       NaN       NaN   NaN
# 9                    NaN       NaN            NaN       NaN       NaN   NaN
# 10                   NaN       NaN            NaN       NaN       NaN   NaN
# 11                   NaN       NaN            NaN       NaN       NaN   NaN
#
#     Code  Quantity  Kupon     Price   Amount_x  ID Nelayan  Sequence 1_x  \
# 0     RC     70.00    0.0   35000.0  2450000.0         0.0           1.0
# 1   MEAT     14.40    0.0  355000.0  5112000.0         0.0           2.0
# 2     RC    100.00    0.0   35000.0  3500000.0         0.0           1.0
# 3   MEAT      9.86    0.0  355000.0  3500300.0         0.0           2.0
# 4     RC     20.00    0.0   35000.0   700000.0         0.0           1.0
# 5    NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 6    NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 7    NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 8    NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 9    NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 10   NaN       NaN    NaN       NaN        NaN         NaN           NaN
# 11   NaN       NaN    NaN       NaN        NaN         NaN           NaN
#
#     Sequence 2_x                PR No Date helper     Date_y   RM      RC  \
# 0            1.0  PR/DOB/20220103/001  2022-01-03 2022-01-03  0.0   70.00
# 1            2.0  PR/DOB/20220103/001  2022-01-03 2022-01-03  0.0   70.00
# 2            1.0  PR/DOB/20220104/001  2022-01-04 2022-01-04  0.0  100.00
# 3            2.0  PR/DOB/20220104/001  2022-01-04 2022-01-04  0.0  100.00
# 4            1.0  PR/DOB/20220105/001  2022-01-05 2022-01-05  0.0   25.00
# 5            NaN                  NaN         NaT        NaT  NaN     NaN
# 6            NaN  PR/DOB/20220107/001  2022-01-07 2022-01-07  0.0  142.60
# 7            NaN  PR/DOB/20220108/001  2022-01-08 2022-01-08  0.0  158.21
# 8            NaN                  NaN         NaT        NaT  NaN     NaN
# 9            NaN                  NaN         NaT        NaT  NaN     NaN
# 10           NaN                  NaN         NaT        NaT  NaN     NaN
# 11           NaN                  NaN         NaT        NaT  NaN     NaN
#
#       %  Total RC  RC Dback  %.1  Total RC Dback   Meat   %.2  Total Meat  \
# 0   1.0     70.00       0.0  0.0             0.0  19.35  0.28       19.35
# 1   1.0     70.00       0.0  0.0             0.0  19.35  0.28       19.35
# 2   1.0    100.00       0.0  0.0             0.0  26.21  0.26       26.21
# 3   1.0    100.00       0.0  0.0             0.0  26.21  0.26       26.21
# 4   1.0     25.00       0.0  0.0             0.0   7.40  0.30        7.40
# 5   NaN       NaN       NaN  NaN             NaN    NaN   NaN         NaN
# 6   1.0    142.60       0.0  0.0             0.0  35.65  0.25       35.65
# 7   1.0    158.21       0.0  0.0             0.0  38.05  0.24       38.05
# 8   NaN       NaN       NaN  NaN             NaN    NaN   NaN         NaN
# 9   NaN       NaN       NaN  NaN             NaN    NaN   NaN         NaN
# 10  NaN       NaN       NaN  NaN             NaN    NaN   NaN         NaN
# 11  NaN       NaN       NaN  NaN             NaN    NaN   NaN         NaN
#
#     Picker Price   Amount_y  Sequence 1_y  Sequence 2_y
# 0           25.0   870750.0           1.0           1.0
# 1           25.0   870750.0           1.0           1.0
# 2           25.0  1179450.0           1.0           1.0
# 3           25.0  1179450.0           1.0           1.0
# 4           25.0   333000.0           1.0           1.0
# 5            NaN        NaN           NaN           NaN
# 6           25.0  1604250.0           1.0           1.0
# 7           25.0  1712250.0           1.0           1.0
# 8            NaN        NaN           NaN           NaN
# 9            NaN        NaN           NaN           NaN
# 10           NaN        NaN           NaN           NaN
# 11           NaN        NaN           NaN           NaN

# %%
df_all_DOB.shape
# Out:
# (12, 42)

# %%
#Menggabungkan semua dataframe
df_all = pd.concat([df_all_BKJ, df_all_DOB])
df_all
# Out:
#               Norm Helper  Delivery Number Tanggal Delivery dari MP  \
# 0   DO/BKJ/20220305/001/1                1               2022-03-05
# 1   DO/BKJ/20220305/001/1                1               2022-03-05
# 2   DO/BKJ/20220307/002/1                2               2022-03-07
# 3   DO/BKJ/20220309/003/1                3               2022-03-09
# 0   DO/DOB/20220104/090/1               90               2022-01-04
# 1   DO/DOB/20220104/090/1               90               2022-01-04
# 2   DO/DOB/20220105/091/1               91               2022-01-05
# 3   DO/DOB/20220105/091/1               91               2022-01-05
# 4   DO/DOB/20220106/092/1               92               2022-01-06
# 5   DO/DOB/20220107/093/1               93               2022-01-07
# 6   DO/DOB/20220108/094/1               94               2022-01-08
# 7   DO/DOB/20220109/095/1               95               2022-01-09
# 8   DO/DOB/20220110/096/1               96               2022-01-10
# 9   DO/DOB/20220111/097/1               97               2022-01-11
# 10  DO/DOB/20220113/098/1               98               2022-01-13
# 11  DO/DOB/20220114/099/1               99               2022-01-14
#
#         Buyer Name    Product Kirim Tanggal Diterima Buyer  \
# 0         PT Prima     Tuna (Whole)             2022-03-06
# 1         PT Prima     Tuna (Whole)             2022-03-06
# 2         PT Prima     Tuna (Whole)             2022-03-08
# 3         PT Prima     Tuna (Whole)             2022-03-10
# 0      SJA Lampung  Rajungan (Meat)             2022-01-05
# 1      SJA Lampung  Rajungan (Meat)             2022-01-05
# 2      SJA Lampung  Rajungan (Meat)             2022-01-06
# 3      SJA Lampung  Rajungan (Meat)             2022-01-06
# 4      SJA Lampung  Rajungan (Meat)             2022-01-07
# 5      SJA Lampung  Rajungan (Meat)             2022-01-08
# 6   Nirwana Segara  Rajungan (Meat)             2022-01-09
# 7   Nirwana Segara  Rajungan (Meat)             2022-01-10
# 8   Nirwana Segara  Rajungan (Meat)             2022-01-11
# 9   Nirwana Segara  Rajungan (Meat)             2022-01-12
# 10  Nirwana Segara  Rajungan (Meat)             2022-01-14
# 11  Nirwana Segara  Rajungan (Meat)             2022-01-15
#
#               PO Number Date Helper     Date_x Month    Year  \
# 0   PO/BKJ/20220305/001  2022-03-05 2022-03-05   Mar  2022.0
# 1   PO/BKJ/20220305/002  2022-03-05 2022-03-05   Mar  2022.0
# 2   PO/BKJ/20220306/001  2022-03-06 2022-03-06   Mar  2022.0
# 3                   NaN         NaT        NaT   NaN     NaN
# 0   PO/DOB/20220103/001  2022-01-03 2022-01-03   Jan  2022.0
# 1   PO/DOB/20220103/002  2022-01-03 2022-01-03   Jan  2022.0
# 2   PO/DOB/20220104/001  2022-01-04 2022-01-04   Jan  2022.0
# 3   PO/DOB/20220104/002  2022-01-04 2022-01-04   Jan  2022.0
# 4   PO/DOB/20220105/001  2022-01-05 2022-01-05   Jan  2022.0
# 5                   NaN         NaT        NaT   NaN     NaN
# 6                   NaN         NaT        NaT   NaN     NaN
# 7                   NaN         NaT        NaT   NaN     NaN
# 8                   NaN         NaT        NaT   NaN     NaN
# 9                   NaN         NaT        NaT   NaN     NaN
# 10                  NaN         NaT        NaT   NaN     NaN
# 11                  NaN         NaT        NaT   NaN     NaN
#
#    Nama Nelayan/Supplier        Type   Source Place      Category     Items  \
# 0                  Nazar  Mini Plant    Bangka Jaya  Ikan Pelagis      Tuna
# 1                   Moza    Supplier    Krueng Mane  Ikan Pelagis      Tuna
# 2                    Gam    Supplier    Bangka Jaya  Ikan Pelagis      Tuna
# 3                    NaN         NaN            NaN           NaN       NaN
# 0            MP Kaiwabar    Satelite       Kaiwabar      Rajungan  Rajungan
# 1                   Inco    Supplier  Kepulauan Aru      Rajungan  Rajungan
# 2            MP Kaiwabar    Satelite       Kaiwabar      Rajungan  Rajungan
# 3                   Inco    Supplier  Kepulauan Aru      Rajungan  Rajungan
# 4            MP Kaiwabar    Satelite       Kaiwabar      Rajungan  Rajungan
# 5                    NaN         NaN            NaN           NaN       NaN
# 6                    NaN         NaN            NaN           NaN       NaN
# 7                    NaN         NaN            NaN           NaN       NaN
# 8                    NaN         NaN            NaN           NaN       NaN
# 9                    NaN         NaN            NaN           NaN       NaN
# 10                   NaN         NaN            NaN           NaN       NaN
# 11                   NaN         NaN            NaN           NaN       NaN
#
#     Size     Code  Quantity  Kupon     Price    Amount_x  ID Nelayan  \
# 0    0.0  TUNA 20    248.00    0.0   29000.0  10664000.0         0.0
# 1    0.0  TUNA 20    252.00    0.0   29000.0  10836000.0         0.0
# 2    0.0  TUNA 20     30.00    0.0   29000.0   1290000.0         0.0
# 3    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 0    0.0       RC     70.00    0.0   35000.0   2450000.0         0.0
# 1    0.0     MEAT     14.40    0.0  355000.0   5112000.0         0.0
# 2    0.0       RC    100.00    0.0   35000.0   3500000.0         0.0
# 3    0.0     MEAT      9.86    0.0  355000.0   3500300.0         0.0
# 4    0.0       RC     20.00    0.0   35000.0    700000.0         0.0
# 5    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 6    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 7    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 8    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 9    NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 10   NaN      NaN       NaN    NaN       NaN         NaN         NaN
# 11   NaN      NaN       NaN    NaN       NaN         NaN         NaN
#
#     Sequence 1_x  Sequence 2_x                PR No Date helper     Date_y  \
# 0            1.0           1.0                  NaN         NaT        NaT
# 1            2.0           2.0                  NaN         NaT        NaT
# 2            1.0           1.0                  NaN         NaT        NaT
# 3            NaN           NaN                  NaN         NaT        NaT
# 0            1.0           1.0  PR/DOB/20220103/001  2022-01-03 2022-01-03
# 1            2.0           2.0  PR/DOB/20220103/001  2022-01-03 2022-01-03
# 2            1.0           1.0  PR/DOB/20220104/001  2022-01-04 2022-01-04
# 3            2.0           2.0  PR/DOB/20220104/001  2022-01-04 2022-01-04
# 4            1.0           1.0  PR/DOB/20220105/001  2022-01-05 2022-01-05
# 5            NaN           NaN                  NaN         NaT        NaT
# 6            NaN           NaN  PR/DOB/20220107/001  2022-01-07 2022-01-07
# 7            NaN           NaN  PR/DOB/20220108/001  2022-01-08 2022-01-08
# 8            NaN           NaN                  NaN         NaT        NaT
# 9            NaN           NaN                  NaN         NaT        NaT
# 10           NaN           NaN                  NaN         NaT        NaT
# 11           NaN           NaN                  NaN         NaT        NaT
#
#      RM      RC    %  Total RC  RC Dback  %.1  Total RC Dback   Meat   %.2  \
# 0   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 1   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 2   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 3   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 0   0.0   70.00  1.0     70.00       0.0  0.0             0.0  19.35  0.28
# 1   0.0   70.00  1.0     70.00       0.0  0.0             0.0  19.35  0.28
# 2   0.0  100.00  1.0    100.00       0.0  0.0             0.0  26.21  0.26
# 3   0.0  100.00  1.0    100.00       0.0  0.0             0.0  26.21  0.26
# 4   0.0   25.00  1.0     25.00       0.0  0.0             0.0   7.40  0.30
# 5   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 6   0.0  142.60  1.0    142.60       0.0  0.0             0.0  35.65  0.25
# 7   0.0  158.21  1.0    158.21       0.0  0.0             0.0  38.05  0.24
# 8   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 9   NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 10  NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
# 11  NaN     NaN  NaN       NaN       NaN  NaN             NaN    NaN   NaN
#
#     Total Meat  Picker Price   Amount_y  Sequence 1_y  Sequence 2_y
# 0          NaN           NaN        NaN           NaN           NaN
# 1          NaN           NaN        NaN           NaN           NaN
# 2          NaN           NaN        NaN           NaN           NaN
# 3          NaN           NaN        NaN           NaN           NaN
# 0        19.35          25.0   870750.0           1.0           1.0
# 1        19.35          25.0   870750.0           1.0           1.0
# 2        26.21          25.0  1179450.0           1.0           1.0
# 3        26.21          25.0  1179450.0           1.0           1.0
# 4         7.40          25.0   333000.0           1.0           1.0
# 5          NaN           NaN        NaN           NaN           NaN
# 6        35.65          25.0  1604250.0           1.0           1.0
# 7        38.05          25.0  1712250.0           1.0           1.0
# 8          NaN           NaN        NaN           NaN           NaN
# 9          NaN           NaN        NaN           NaN           NaN
# 10         NaN           NaN        NaN           NaN           NaN
# 11         NaN           NaN        NaN           NaN           NaN

# %%
df_all.shape
# Out:
# (16, 42)

# %%
#Save file to parquet
df_all.to_parquet('transactions_all.parquet', index=False)
df_all_BKJ.to_parquet('transactions_BKJ.parquet', index=False)
df_all_DOB.to_parquet('transactions_DOB.parquet', index=False)
df_all_processing.to_parquet('transactions_processing.parquet', index=False)
df_all_buying.to_parquet('transactions_buying.parquet', index=False)
df_all_delivery.to_parquet('transactions_delivery.parquet', index=False)
#Menyimpan file parquet di Google Drive
# !cp transactions_all.parquet "drive/My Drive/Output"
# !cp transactions_BKJ.parquet "drive/My Drive/Output"
# !cp transactions_DOB.parquet "drive/My Drive/Output"
# !cp transactions_processing.parquet "drive/My Drive/Output"
# !cp transactions_buying.parquet "drive/My Drive/Output"
# !cp transactions_delivery.parquet "drive/My Drive/Output"
